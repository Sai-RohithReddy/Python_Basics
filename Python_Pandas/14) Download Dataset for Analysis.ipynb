# %%
# Download Dataset from Kaggle, mostly Datasets will be in .xlsx or .csv format

# %%
import pandas as pd
d = pd.read_csv('Tokyo2021.csv')
df = pd.DataFrame(d)
df
# Out:
#                        Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0     United States of America          39            41            33    113
# 1   People's Republic of China          38            32            18     88
# 2                        Japan          27            14            17     58
# 3                Great Britain          22            21            22     65
# 4                          ROC          20            28            23     71
# ..                         ...         ...           ...           ...    ...
# 88                       Ghana           0             0             1      1
# 89                     Grenada           0             0             1      1
# 90                      Kuwait           0             0             1      1
# 91         Republic of Moldova           0             0             1      1
# 92        Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# ...

# %%
# for getting top five rows
df.head()
# Out:
#                       Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0    United States of America          39            41            33    113
# 1  People's Republic of China          38            32            18     88
# 2                       Japan          27            14            17     58
# 3               Great Britain          22            21            22     65
# 4                         ROC          20            28            23     71
#
#    Rank By Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3

# %%
# for bottom five

df.tail()
# Out:
#                  Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 88                 Ghana           0             0             1      1
# 89               Grenada           0             0             1      1
# 90                Kuwait           0             0             1      1
# 91   Republic of Moldova           0             0             1      1
# 92  Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# 88             77
# 89             77
# 90             77
# 91             77
# 92             77

# %%
# sorting based on column
df.sort_values('Rank By Total')
# Out:
#                        Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0     United States of America          39            41            33    113
# 1   People's Republic of China          38            32            18     88
# 4                          ROC          20            28            23     71
# 3                Great Britain          22            21            22     65
# 2                        Japan          27            14            17     58
# ..                         ...         ...           ...           ...    ...
# 76                     Bahrain           0             1             0      1
# 62                     Bermuda           1             0             0      1
# 63                     Morocco           1             0             0      1
# 81                Turkmenistan           0             1             0      1
# 92        Syrian Arab Republic           0             0             1      1
#
#     Rank By Total
# ...

# %%
# sorting in decenting order
df.sort_values('Rank By Total',ascending = False)
# Out:
#                        Country  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 92        Syrian Arab Republic           0             0             1      1
# 64                 Puerto Rico           1             0             0      1
# 62                     Bermuda           1             0             0      1
# 76                     Bahrain           0             1             0      1
# 77                Saudi Arabia           0             1             0      1
# ..                         ...         ...           ...           ...    ...
# 2                        Japan          27            14            17     58
# 3                Great Britain          22            21            22     65
# 4                          ROC          20            28            23     71
# 1   People's Republic of China          38            32            18     88
# 0     United States of America          39            41            33    113
#
#     Rank By Total
# ...
