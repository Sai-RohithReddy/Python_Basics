# %%
dbutils.fs.rm('/FileStore/tables', True)
# Out:
# Out[4]: True

# %% [markdown]
# # Extracting Data

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('ETL').getOrCreate()

df = spark.read.text('/FileStore/tables/WordData.txt')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>This is a Japanese doll</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td></tr><tr><td>As the years pass by we all know owners look more and more like their dogs</td></tr><tr><td>If you don't like toenails you probably shouldn't look at your feet</td></tr><tr><td>He was disappointed when he found the beach to be so sandy and the sun so sunny</td></tr><tr><td>When he encountered maize for the first time he thought it incredibly corny</td></tr><tr><td>Situps are a terrible way to end your day</td></tr><tr><td>Toddlers feeding raccoons surprised even the seasoned park ranger</td></tr><tr><td>Edith could decide if she should paint her teeth or brush her nails</td></tr><tr><td>Her daily goal was to improve on yesterday</td></tr><tr><td>Tomorrow will bring something new so leave today as a memory</td></tr><tr><td>His son quipped that power bars were nothing more than adult candy bars</td></tr><tr><td>He wondered why at 18 he was old enough to go to war but not old enough to buy cigarettes</td></tr><tr><td>If my calculator had a history it would be more embarrassing than my browser history</td></tr><tr><td>The hummingbird's wings blurred while it eagerly sipped the sugar water from the feeder</td></tr><tr><td>He went on a whiskey diet and immediately lost three days</td></tr><tr><td>This is the last random sentence I will be writing and I am going to stop mid-sent</td></tr><tr><td>I come from a tribe of head-hunters so I will never need a shrink</td></tr><tr><td>The delicious aroma from the kitchen was ruined by cigarette smoke</td></tr><tr><td>Weather is not trivial - it's especially important when you're standing in it</td></tr><tr><td>She had a difficult time owning up to her own crazy self</td></tr><tr><td>Gary didn't understand why Doug went upstairs to get one dollar bills when he invited him to go cow tipping</td></tr><tr><td>He loved eating his bananas in hot dog buns</td></tr><tr><td>Peanut butter and jelly caused the elderly lady to think about her past</td></tr><tr><td>We have never been to Asia nor have we visited Africa</td></tr><tr><td>A dead duck doesn't fly backward</td></tr><tr><td>Having no hair made him look even hairier</td></tr><tr><td>The secret ingredient to his wonderful life was crime</td></tr><tr><td>He played the game as if his life depended on it and the truth was that it did</td></tr><tr><td>Baby wipes are made of chocolate stardust</td></tr><tr><td>He is no James Bond his name is Roger Moore</td></tr><tr><td>A quiet house is nice until you are ordered to stay in it for months</td></tr><tr><td>His thought process was on so many levels that he gave himself a phobia of heights</td></tr><tr><td>Please tell me you don't work in a morgue</td></tr><tr><td>The book is in front of the table</td></tr><tr><td>The lake is a long way from here</td></tr><tr><td>She learned that water bottles are no longer just to hold liquid but they're also status symbols</td></tr><tr><td>Poison ivy grew through the fence they said was impenetrable</td></tr><tr><td>Henry couldn't decide if he was an auto mechanic or a priest</td></tr><tr><td>I would be delighted if the sea were full of cucumber juice</td></tr><tr><td>The best part of marriage is animal crackers with peanut butter</td></tr><tr><td>You have every right to be angry but that doesn't give you the right to be mean</td></tr><tr><td>I want a giraffe but I'm a turtle eating waffles</td></tr><tr><td>Erin accidentally created a new universe</td></tr><tr><td>He was so preoccupied with whether or not he could that he failed to stop to consider if he should</td></tr><tr><td>The bird had a belief that it was really a groundhog</td></tr><tr><td>Even with the snow falling outside she felt it appropriate to wear her bikini</td></tr><tr><td>Separation anxiety is what happens  ...

# %% [markdown]
# # Transforming Data

# %%
from pyspark.sql.functions import lit, col, explode
import pyspark.sql.functions as f

# %%
df1 = df.withColumn('splitedData', f.split('value', ' '))
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th><th>splitedData</th></tr></thead><tbody><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td></tr><tr><td>As the years pass by we all know owners look more and more like their dogs</td><td>List(As, the, years, pass, by, we, all, know, owners, look, more, and, more, like, their, dogs)</td></tr><tr><td>If you don't like toenails you probably shouldn't look at your feet</td><td>List(If, you, don't, like, toenails, you, probably, shouldn't, look, at, your, feet)</td></tr><tr><td>He was disappointed when he found the beach to be so sandy and the sun so sunny</td><td>List(He, was, disappointed, when, he, found, the, beach, to, be, so, sandy, and, the, sun, so, sunny)</td></tr><tr><td>When he encountered maize for the first time he thought it incredibly corny</td><td>List(When, he, encountered, maize, for, the, first, time, he, thought, it, incredibly, corny)</td></tr><tr><td>Situps are a terrible way to end your day</td><td>List(Situps, are, a, terrible, way, to, end, your, day)</td></tr><tr><td>Toddlers feeding raccoons surprised even the seasoned park ranger</td><td>List(Toddlers, feeding, raccoons, surprised, even, the, seasoned, park, ranger)</td></tr><tr><td>Edith could decide if she should paint her teeth or brush her nails</td><td>List(Edith, could, decide, if, she, should, paint, her, teeth, or, brush, her, nails)</td></tr><tr><td>Her daily goal was to improve on yesterday</td><td>List(Her, daily, goal, was, to, improve, on, yesterday)</td></tr><tr><td>Tomorrow will bring something new so leave today as a memory</td><td>List(Tomorrow, will, bring, something, new, so, leave, today, as, a, memory)</td></tr><tr><td>His son quipped that power bars were nothing more than adult candy bars</td><td>List(His, son, quipped, that, power, bars, were, nothing, more, than, adult, candy, bars)</td></tr><tr><td>He wondered why at 18 he was old enough to go to war but not old enough to buy cigarettes</td><td>List(He, wondered, why, at, 18, he, was, old, enough, to, go, to, war, but, not, old, enough, to, buy, cigarettes)</td></tr><tr><td>If my calculator had a history it would be more embarrassing than my browser history</td><td>List(If, my, calculator, had, a, history, it, would, be, more, embarrassing, than, my, browser, history)</td></tr><tr><td>The hummingbird's wings blurred while it eagerly sipped the sugar water from the feeder</td><td>List(The, hummingbird's, wings, blurred, while, it, eagerly, sipped, the, sugar, water, from, the, feeder)</td></tr><tr><td>He went on a whiskey diet and immediately lost three days</td><td>List(He, went, on, a, whiskey, diet, and, immediately, lost, three, days)</td></tr><tr><td>This is the last random sentence I will be writing and I am going to stop mid-sent</td><td>List(This, is, the, last, random, sentence, I, will, be, writing, and, I, am, going, to, stop, mid-sent)</td></tr><tr><td>I come from a tribe of head-hunters so I will never need a shrink</td><td>List(I, come, from, a, tribe, of, head-hunters, so, I, will, never, need, a, shrink)</td></tr><tr><td>The delicious aroma from the kitchen was ruined by cigarette smoke</td><td>List(The, delicious, aroma, from, the, kitchen, was, ruined, by, cigarette, smoke)</td></tr><tr><td>Weather is not trivial - it's especially important when you're standing in it</td><td>List(Weather, is, not, trivial, -, it's, especially, important, when, you're, standing, in, it)</td></tr><tr><td>She had a difficult time owning up to her own crazy self</td><td>List(She, had, a, difficult, time, owning, up, to, her, own, crazy, self)</td></tr><tr><td>Gary didn't understand why Doug went upstairs to get one  ...

# %%
df2 = df1.withColumn('wordsData', explode('splitedData'))
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th><th>splitedData</th><th>wordsData</th></tr></thead><tbody><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td><td>This</td></tr><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td><td>is</td></tr><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td><td>a</td></tr><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td><td>Japanese</td></tr><tr><td>This is a Japanese doll</td><td>List(This, is, a, Japanese, doll)</td><td>doll</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>The</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>team</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>members</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>were</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>hard</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>to</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>tell</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>apart</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>since</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>they</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>all</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>wore</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>their</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ponytail</td><td>List(The, team, members, were, hard, to, tell, apart, since, they, all, wore, their, hair, in, a, ponytail)</td><td>hair</td></tr><tr><td>The team members were hard to tell apart since they all wore their hair in a ...

# %%
wordsDF = df2.select(df2.wordsData)
display(wordsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>wordsData</th></tr></thead><tbody><tr><td>This</td></tr><tr><td>is</td></tr><tr><td>a</td></tr><tr><td>Japanese</td></tr><tr><td>doll</td></tr><tr><td>The</td></tr><tr><td>team</td></tr><tr><td>members</td></tr><tr><td>were</td></tr><tr><td>hard</td></tr><tr><td>to</td></tr><tr><td>tell</td></tr><tr><td>apart</td></tr><tr><td>since</td></tr><tr><td>they</td></tr><tr><td>all</td></tr><tr><td>wore</td></tr><tr><td>their</td></tr><tr><td>hair</td></tr><tr><td>in</td></tr><tr><td>a</td></tr><tr><td>ponytail</td></tr><tr><td>As</td></tr><tr><td>the</td></tr><tr><td>years</td></tr><tr><td>pass</td></tr><tr><td>by</td></tr><tr><td>we</td></tr><tr><td>all</td></tr><tr><td>know</td></tr><tr><td>owners</td></tr><tr><td>look</td></tr><tr><td>more</td></tr><tr><td>and</td></tr><tr><td>more</td></tr><tr><td>like</td></tr><tr><td>their</td></tr><tr><td>dogs</td></tr><tr><td>If</td></tr><tr><td>you</td></tr><tr><td>don't</td></tr><tr><td>like</td></tr><tr><td>toenails</td></tr><tr><td>you</td></tr><tr><td>probably</td></tr><tr><td>shouldn't</td></tr><tr><td>look</td></tr><tr><td>at</td></tr><tr><td>your</td></tr><tr><td>feet</td></tr><tr><td>He</td></tr><tr><td>was</td></tr><tr><td>disappointed</td></tr><tr><td>when</td></tr><tr><td>he</td></tr><tr><td>found</td></tr><tr><td>the</td></tr><tr><td>beach</td></tr><tr><td>to</td></tr><tr><td>be</td></tr><tr><td>so</td></tr><tr><td>sandy</td></tr><tr><td>and</td></tr><tr><td>the</td></tr><tr><td>sun</td></tr><tr><td>so</td></tr><tr><td>sunny</td></tr><tr><td>When</td></tr><tr><td>he</td></tr><tr><td>encountered</td></tr><tr><td>maize</td></tr><tr><td>for</td></tr><tr><td>the</td></tr><tr><td>first</td></tr><tr><td>time</td></tr><tr><td>he</td></tr><tr><td>thought</td></tr><tr><td>it</td></tr><tr><td>incredibly</td></tr><tr><td>corny</td></tr><tr><td>Situps</td></tr><tr><td>are</td></tr><tr><td>a</td></tr><tr><td>terrible</td></tr><tr><td>way</td></tr><tr><td>to</td></tr><tr><td>end</td></tr><tr><td>your</td></tr><tr><td>day</td></tr><tr><td>Toddlers</td></tr><tr><td>feeding</td></tr><tr><td>raccoons</td></tr><tr><td>surprised</td></tr><tr><td>even</td></tr><tr><td>the</td></tr><tr><td>seasoned</td></tr><tr><td>park</td></tr><tr><td>ranger</td></tr><tr><td>Edith</td></tr><tr><td>could</td></tr><tr><td>decide</td></tr><tr><td>if</td></tr><tr><td>she</td></tr><tr><td>should</td></tr><tr><td>paint</td></tr><tr><td>her</td></tr><tr><td>teeth</td></tr><tr><td>or</td></tr><tr><td>brush</td></tr><tr><td>her</td></tr><tr><td>nails</td></tr><tr><td>Her</td></tr><tr><td>daily</td></tr><tr><td>goal</td></tr><tr><td>was</td></tr><tr><td>to</td></tr><tr><td>improve</td></tr><tr><td>on</td></tr><tr><td>yesterday</td></tr><tr><td>Tomorrow</td></tr><tr><td>will</td></tr><tr><td>bring</td></tr><tr><td>something</td></tr><tr><td>new</td></tr><tr><td>so</td></tr><tr><td>leave</td></tr><tr><td>today</td></tr><tr><td>as</td></tr><tr><td>a</td></tr><tr><td>memory</td></tr><tr><td>His</td></tr><tr><td>son</td></tr><tr><td>quipped</td></tr><tr><td>that</td></tr><tr><td>power</td></tr><tr><td>bars</td></tr><tr><td>were</td></tr><tr><td>nothing</td></tr><tr><td>more</td></tr><tr><td>than</td></tr><tr><td>adult</td></tr><tr><td>candy</td></tr><tr><td>bars</td></tr><tr><td>He</td></tr><tr><td>wondered</td></tr><tr><td>why</td></tr><tr><td>at</td></tr><tr><td>18</td></tr><tr><td>he</td></tr><tr><td>was</td></tr><tr><td>old</td></tr><tr><td>enough</td></tr><tr><td>to</td></tr><tr><td>go</td></tr><tr><td>to</td></tr><tr><td>war</td></tr><tr><td>but</td></tr><tr><td>not</td></tr><tr><td>old</td></tr><tr><td>enough</td></tr><tr><td>to</td></tr><tr><td>buy</td></tr><tr><td>cigarettes</td></tr><tr><td>If</td></tr><tr><td>my</td></tr><tr><td>calculator</td></tr><tr><td>had</td></tr><tr><td>a</td></tr><tr><td>history</td></tr><tr><td>it</td></tr><tr><td>would</td></tr><tr><td>be</td></tr><tr><td>more</td></tr><tr><td ...

# %%
countDF = wordsDF.groupBy('wordsData').count()
countDF.show()
# Out:
# +-----------+-----+
# |  wordsData|count|
# +-----------+-----+
# |   Tomorrow|    4|
# |         If|    8|
# |      leave|    4|
# |      corny|    4|
# |        day|    4|
# |preoccupied|    4|
# |       even|    8|
# |      crazy|    4|
# |    bananas|    4|
# |     priest|    4|
# |        did|    4|
# |    whether|    4|
# |     Having|    4|
# |        I'm|    4|
# |      crime|    4|
# |  surprised|    4|
# |      James|    4|
# |      could|    8|
# |        buy|    4|
# |        him|    8|
# +-----------+-----+
# only showing top 20 rows

# %% [markdown]
# # Loading Data

# %%
# Create AWS RDS and connect it to pgAdmin

# %%
driver = 'org.postgresql.Driver'
url = 'jdbc:postgresql://database-1.c1catb0at1ho.us-east-1.rds.amazonaws.com/'
table = 'rohith_schema_pyspark.WorkCount'
user = 'postgres'
password = 'root1234'

# %%
countDF.write.format('jdbc').option('driver', driver).option('url', url).option('dbtable', table).option('mode', 'append').option('user', user).option('password', password).save()
